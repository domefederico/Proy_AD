# %% [markdown]
# ## Proyecto Mushroom dataset

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import re
import seaborn as sns

# %%
df = pd.read_csv('MushroomDataset/secondary_data.csv', low_memory=False)
